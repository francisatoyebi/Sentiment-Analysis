# %%
data = {}
i = 0
import csv
with open('Data/Hotel_reviews_dataset.csv', 'r') as cssv:
    for row in csv.reader(cssv):
        data[i] = row
        i += 1

# %%
data
# Out:
# {0: ['Text', 'Sentiment'],
#  1: ['The rooms are extremely small, practically only a bed.', 'negative'],
#  2: ['Room safe did not work.', 'negative'],
#  3: ['Mattress very comfortable.', 'positive'],
#  4: ['Very uncomfortable, thin mattress, with plastic cover that rustles every time you move.',
#   'negative'],
#  5: ['No bathroom in room', 'negative'],
#  6: ['The bed was soooo comfy.', 'positive'],
#  7: ['someone must have been smoking in the room next door.', 'negative'],
#  8: ['The bed is very comfortable.', 'positive'],
#  9: ['Very spacious rooms, quiet and very comfortable.', 'positive'],
#  10: ['For 3 people in a bedroom the sofa bed is a bit unconfortable.',
#   'negative'],
#  11: ['Lights in the common room were too dim.', 'negative'],
#  12: ['Air conditioning working fine.', 'positive'],
#  13: ["So if you're the type that likes to let water run a bit before getting wet or it takes a minute to figure out how to make it hot, you're gonna get wet.",
#   'negative'],
#  14: ['the windows are only single glazed so the heat could escape- although to be fair it was -6 outside!',
#   'negative'],
#  15: ['Terrible, small cubbyholes, which are marketed as rooms.', 'negative'],
#  16: ['Corridors filthy\nRoom filthy\nElectrical cables in room not safe\nWhole building smelly\nShower repulsive',
#   'negative'],
#  17: ['walls seem to have no sound insulation', 'negative'],
#  18: ['The gym was very small and basic', 'negative'],
#  19: ['The mattresses were too "springy" and uncomfortable.', 'negative'],
#  20: ['very light and the comfy of the bed was unbeatable.', 'negative'],
#  21: ['Shows some wear and tear.', 'negative'],
#  22: ['Some thinks didnt work well : air, tv , open windows,', 'negative'],
#  23: ['Microwave needed!', 'negative'],
#  24: ["Room wasn't cleaned or bed made up", 'negative'],
#  25: ['The room had cable TV, a safe, an iron, a hairdryer and free coffee & tea in the downstairs area.',
#   'positive'],
#  26: ['The heat in the room fluctuated -- at times it felt a little draft, and on my last night, the fan was really loud.',
#   'negative'],
#  27: ['The building was under renovation,', 'positive'],
#  28: ['The water pressure was not that strong in the shower.', 'negative'],
#  29: ['Room too small to open suitcase.', 'negative'],
#  30: ['no elevator might be a challenge for some people', 'negative'],
#  31: ['Pay extra.. :( Room was tiny', 'negative'],
#  32: ['and hip and CLEAN!', 'positive'],
#  33: ['Comfortable bed and selection of pillows.', 'positive'],
#  34: ['The TV was not working.', 'negative'],
#  35: ['The walk up 4 stories', 'negative'],
#  36: ["Hallways to room stale and didn't feel clean.", 'negative'],
#  37: ['there was a building under construction across the road which was extremely noisy throughout the day.',
#   'negative'],
#  38: ['Bathtub not clean.', 'negative'],
#  39: ['Hot water was abundant and the A/C (window unit) was ice cold - Excellent!',
#   'positive'],
#  40: ['Access to fitness facilities, especially the pool was a real value added.',
#   'positive'],
#  41: ['Barely room for anything else than sleep.', 'negative'],
#  42: ['Lift was a bit of a pain with card access.', 'negative'],
#  43: ["Could have used a little more counter room in bath and we didn't think the restaurant looked very inviting compared to the rest of the hotel.",
#   'negative'],
#  44: ['The bed was highly uncomfortable, although the engineer fixed it',
#   'negative'],
#  45: ["The memory foam mattress - we all agreed the best night's sleep in a hotel EVER...",
#   'positive'],
#  46: ["Toilet paper wasn't replaced everyday!", 'negative'],
#  47: ['The extra beds are not the greatest (a futon and a sleeper couch)',
#   'negative'],
#  48: ['Room was extremely cramped.', 'negative'],
#  49: ['Shower cap n sanitary bags not available in the room.', 'negative'],
#  50: ['it was freezing cold in my room for the night I stayed.', 'negative'],
#  51: ['Outside seating was lovely', 'negative'],
#  52: ['The heating was unbelievably noisy during the night.', 'negative'],
#  53: ['bed, smell.', 'negative'],
#  54: ['Bathroom area large would have been nice with a bathtub.', 'positive'],
#  55: ['Shared restrooms do not support many rooms and/or many people.',
#   'negative'],
#  56: ['Stiff feel to the place- no amenities.', 'negative'],
#  57: ['Lovely room, bed was so comfortable!', 'positive'],
#  58: ['Every 15 minutes door were slamming & lights on.', 'negative'],
#  59: ['After that time, mostly quiet apart from some door slamming by other guests.',
#   'negative'],
#  60: ['The top of the window was then covered by the dirty blind.',
#   'negative'],
#  61: ['Detest the glass "door" if shower/tub .. with?', 'negative'],
#  62: ['this was expected, clean towels and room cleaned every day.',
#   'positive'],
#  63: ['Barely a few degrees warmer than outside during winter, so I had to rug up and wear shoes to use the toilet.',
#   'negative'],
#  64: ['ac was terrible', 'negative'],
#  65: ['More plug outlets with surge protectors.', 'negative'],
#  66: ['Just to give you an idea: the shutters of the windows were not working, did not go neither up or down - just hanging down only one side and the other up....',
#   'negative'],
#  67: ['The phone in my room was not working.', 'negative'],
#  68: ['Elevators are slow, very long lines.', 'negative'],
#  69: ['Location anda facilities', 'positive'],
#  70: ['There was also  garbage in our kitchen - there were isntant coffee packages left from previous customers.',
#   'negative'],
#  71: ['Amazing facilities.', 'positive'],
#  72: ['Only one elevator ,', 'negative'],
#  73: ['Room was very spacious', 'positive'],
#  74: ['The bathroom is dirty.', 'negative'],
#  75: ['Roof terrace great', 'negative'],
#  76: ['No tea or coffee making facilities in the rooms', 'negative'],
#  77: ['the room had aircon and we had earplugs and slept soundly.',
#   'positive'],
#  78: ['Also, when the bright bathroom lights are turned on, it lights up the whole hotel room, shining thru the frosted glass panels.',
#   'negative'],
#  79: ['The Bed was SUPER COMFY !', 'positive'],
#  80: ['Bathroom was extra small,', 'negative'],
#  81: ['Rooms are cosy with great temperature control.', 'positive'],
#  82: ['Facilities were very clean.', 'positive'],
#  83: ["only if you don't mind stains in your bed sheets or cockroaches in your (shared) bathroom.",
#   'negative'],
#  84: ['The bathroom functioned o.k.', 'negative'],
#  85: ['Poor TV picture and channel selection.', 'negative'],
#  86: ['No elevator.', 'negative'],
#  87: ['essential gym to allow for some workout.', 'positive'],
#  88: ['Rooms quite small for price, especially if you use a travel cot.',
#   'negative'],
#  89: ['room was not at all inviting.', 'negative'],
#  90: ['Wifi connected', 'negative'],
#  91: ['Everything was very clean.', 'positive'],
#  92: ["Windows haven't been cleaned for years (if ever).", 'negative'],
#  93: ['Showers could do with some renovations - they seem clean,', 'negative'],
#  94: ['Only cold water came out.', 'negative'],
#  95: ["the Persian decor is so half-hearted it - I'd take down the 5 lengths of Turkish bunting lanterns above the glass roofed bar or cover the whole area with them - 30 more (!)",
#   'negative'],
#  96: ['The toilet ran until you jiggled the handle.', 'negative'],
#  97: ['The bed was terrible and not comfortable at all', 'negative'],
#  98: ['Mattresses and linens were all great.', 'positive'],
#  99: ['No wardrobe, no space for luggage, no towel change, walls are not sound proof thus very noisy.',
#   'negative'],
#  100: ['The elevators were fast - never we had to wait long for a one.On 15th floor the city noise was not bothering at all and after the whole day walking around we were sleeping execellent.',
#   'positive'],
#  101: ['Has most things you need.', 'positive'],
#  102: ['Bed was not a full size 2,40 cm long bed, they were smaller.',
#   'negative'],
#  103: ['very spartan.', 'negative'],
#  104: ['Room extremely small.', 'negative'],
#  105: ['No walls mean oher guests being loud at all hrs.', 'negative'],
#  106: ['Very nice rooftop terrace, and gym.', 'positive'],
#  107: ['Wallpaper is peeking off in places.', 'negative'],
#  108: ['Insufficient and hard to reach plugs to charge devices.', 'negative'],
#  109: ["Mouse in the room,\nNo Wifi,\nNo cleaning service in 3 days,\nNo elevators,\nDoors to outside of hotel didn't lock anymore,\nOn main avenue, with constructions, one of our room was pretty loud.",
#   'negative'],
#  110: ['No bath, only a shower, and I requested 2 queen size beds',
#   'negative'],
#  111: ["I called and they just hadn't received the shipment of clean towels.",
#   'negative'],
#  112: ['The room was clean.', 'positive'],
#  113: ['I don\'t mind the small space,\njust would have liked a bit more "style."',
#   'negative'],
#  114: ['King Room was spacious with plenty of room to spread out and unpack, especially awesome for an extended stay.',
#   'positive'],
#  115: ['Hotel was very clean and had character.', 'positive'],
#  116: ['on HVAC vent.', 'negative'],
#  117: ['We just had to place our luggage on the floor.', 'negative'],
#  118: ['Unclean bathrooms.', 'negative'],
#  119: ['Only negative was the old and very loud air conditioning in the rooms.',
#   'negative'],
#  120: ['there was dust and tissue under the bed.', 'negative'],
#  121: ['The bed was very comfy & the room spacious.', 'positive'],
#  122: ['No air conditioning.', 'negative'],
#  123: ["Bath and shower were in poor condition and didn''t hold the water.",
#   'negative'],
#  124: ['I was told I would have two double beds.', 'negative'],
#  125: ['Bathroom and shower were very good!, lighting as well.', 'positive'],
#  126: ['Rooms too small.', 'negative'],
#  127: ['Our room had left over garbage from whomever stayed there prior.',
#   'negative'],
#  128: ['The floor was not very clean.', 'negative'],
#  129: ['Very comfortable beds.', 'positive'],
#  130: ['The only area of improvement would be the fitness center.',
#   'negative'],
#  131: ['The pool is the best!', 'positive'],
#  132: ['good soundproofing to windows), great showerroom with excellent hot shower, good air con, free wifi and coffee maker.',
#   'positive'],
#  133: ['5 star qualiity towels and linen.', 'positive'],
#  134: ['we only had 7 channels which four of them werent in english.',
#   'negative'],
#  135: ["It's much more potent and pleasant than\nany Febreeze scent.\n",
#   'positive'],
#  136: ["Some have small televisions, flat screen, or the old 1990's tube, as well as, some of the rooms do not have that amenity.I usually book a double room, which thus far comes with a window and is a bit more spacious.The single rooms are much smaller, yet comfortable.",
#   'positive'],
#  137: ['Room was large for my family of 4 adults.', 'positive'],
#  138: ['My room was pretty soulless, although it did have a great view.',
#   'negative'],
#  139: ['The room itself was very clean.', 'positive'],
#  140: ['My room was immaculate and smelled so fresh and clean.', 'positive'],
#  141: ['quiet place.', 'positive'],
#  142: ["The room was a nice size, big enough for both my and my friend's huge suitcases to fit on the floor and for us to still move around.",
#   'positive'],
#  143: ['The hotel was very clean.', 'positive'],
#  144: ['No kettle, had to use a coffee maker to boil water for tea which was tricky as it had to be rinsed through many times.',
#   'negative'],
#  145: ['Rooms were spotless and classy.', 'positive'],
#  146: ['The front entrance could use some curb appeal.', 'negative'],
#  147: ['Bathroom was way too retro.......shower was very poor... no hand shower, poor water pressure and way too narrow.......It also had a plastic curtain which for a $650 dollar hotel room is way too nasty.',
#   'negative'],
#  148: ['extra small rooms.', 'negative'],
#  149: ['Poor beds quality, very very noisy : would have been the same if we would have no windows.',
#   'negative'],
#  150: ['The bathrooms have frosted glass walls,not private at all.',
#   'negative'],
#  151: ["Rooms are cold and you can't adjust the temperature and also heating works only a few hours in the morning.",
#   'negative'],
#  152: ['very loud construction noise out front of our window.', 'negative'],
#  153: ['The room was interior so no traffic noise.', 'positive'],
#  154: ['Room was noisy and cold.', 'negative'],
#  155: ['The air-con was too noisy to leave on for too long.', 'negative'],
#  156: ['still easy to reach.', 'positive'],
#  157: ["The front door didn't work so we had to pry it open.", 'negative'],
#  158: ['The bed is really terrible,especially the blanket is heavy and terrible terrible quality.',
#   'negative'],
#  159: ["Bathroom sink tap leaked and aircon didn't work properly", 'negative'],
#  160: ["We didn't like the mouse in the room.", 'negative'],
#  161: ['Decent room', 'positive'],
#  162: ['Loved the elegant art deco ambience.', 'positive'],
#  163: ['Broken tiles in shower.', 'negative'],
#  164: ['In the shower it was turned down as cold as it could be and it was still hotter than I would usually have it.',
#   'negative'],
#  165: ['Bed was hard and sheets were rough.', 'negative'],
#  166: ['I loved that there was a coffee shop\nunderneath, and it closed at 12am every night, so that I can get my late\nnight coffee, if I wanted.',
#   'positive'],
#  167: ['Dimly lit.', 'negative'],
#  168: ['The towels had holes in them.', 'negative'],
#  169: ['The hotel  advertised AC as one of its amenities in its booking.com descriptions!',
#   'negative'],
#  170: ['The bed was super comfortable and the bathtub with jets was awesome too.',
#   'positive'],
#  171: ['We actually enjoyed how small our room was because we knew about it ahead of time and wanted to try something really different.',
#   'positive'],
#  172: ['Bedding was changed once,', 'negative'],
#  173: ['The same counts for the bathroom, especially the shower was great.',
#   'positive'],
#  174: ['The hotel has a rooftop with a hot tub which has an awesome view.',
#   'positive'],
#  175: ['It was quiet.', 'positive'],
#  176: ['Rooms are small,', 'negative'],
#  177: ['The drapes could have fit the window.', 'negative'],
#  178: ['It was very not comfortable.', 'positive'],
#  179: ['Facilities were great.', 'positive'],
#  180: ['Just one bed so in your room you always have to sit on the bed.',
#   'negative'],
#  181: ['So there could have been more convenient outlets.', 'negative'],
#  182: ['The exercise room closest to my floor was filled with big screen TVs and sheets covering them.',
#   'negative'],
#  183: ['a bit tight to make people either pay or leave yr room.', 'negative'],
#  184: ['Shower was intense.', 'positive'],
#  185: ['The bed was very comfortable, and room minimalist', 'positive'],
#  186: ["Rooms aren't very sound proof from hallway sounds.", 'negative'],
#  187: ['Cool design.', 'positive'],
#  188: ['Our room was very spacious, especially for NYC.', 'positive'],
#  189: ['The main lobby is nice', 'positive'],
#  190: ['Carpets are coming unstitched.', 'negative'],
#  191: ['It was bigger so that was nice!', 'negative'],
#  192: ['Room was not cleaned even once during our stay.', 'negative'],
#  193: ['Room not what we ordered or prepaid for.', 'negative'],
#  194: ['The room needed to be painted,', 'negative'],
#  195: ['Sep 5-8 room 302\nRoom was too small, the shower pressure was good.',
#   'negative'],
#  196: ['Very large for Manhattan with good sized bed, flat screen TV & ample closet.',
#   'positive'],
#  197: ['Waited over 40 minutes to use shower.', 'negative'],
#  198: ['The lifts worked!', 'positive'],
#  199: ['Elevators tend to be slow...', 'negative'],
#  200: ['Crumbs from snacks were not cleaned up for 3 days!!', 'negative'],
#  201: ['the bathroom was a little dirty with hair at the walls', 'negative'],
#  202: ['We had requested two queen beds and got a room with 1 queen and 2 twins, we were advised that there were not any other rooms and could put the (2) beds together, which we did and it was no issue as far as sleeping.',
#   'negative'],
#  203: ['Noisy noisy suite on 4th floor.', 'negative'],
#  204: ['no way to lock the door.', 'negative'],
#  205: ['I was also overcharged for dry cleaning.', ''],
#  206: ['Perfect breakfast, great start for the day.', ''],
#  207: ['nice staff.', ''],
#  208: ["Perfect location, can't be  better, close to everything, this is the place.",
#   ''],
#  209: ['People at the reception desk were very kind and helpful.', ''],
#  210: ['The breakfast was light (coffee and cookies).', ''],
#  211: ['Great price for a solo business traveler.', ''],
#  212: ['Others familiar with New York said that it was good value.', ''],
#  213: ['Great location.', ''],
#  214: ["Location is the best to me, and to you also if you don't mind the Hong Kong or south China living atmosphere down in the surrounding streets.",
#   ''],
#  215: ['5 minutes via subway.', ''],
#  216: ['Within walking distance of the Empire State Building, Times Square, Central Park and grand central was just around the corner if you prefer to take a train or subway.',
#   ''],
#  217: ['It took 40 minutes to get a clean towel after using the app on their tablet.',
#   ''],
#  218: ['Location is brilliant - a block and a half from Grand Central Station.',
#   ''],
#  219: ['Being in the heart of Times Square made everything convinient.', ''],
#  220: ['The helpful and efficient staff.', ''],
#  221: ['Being charged for internet usage, also being charged for using their computer to print out boarding passes.',
#   ''],
#  222: ['The central location made it very easy to get to all the main tourist attractions, both on foot or by subway.',
#   ''],
#  223: ['close to Grand Central, which was convenient for last minute meals.',
#   ''],
#  224: ['The price was right, we only needed a bed to sleep,\nBathroom and showers were clean, room was clean.',
#   ''],
#  225: ['Only a few steps from subway.', ''],
#  226: ['Close to several Shops restaurants, Starbucks :-)', ''],
#  227: ['price of accomodation is over priced for what its worth.', ''],
#  228: ['These exceeded my expectations for a BnB in this price range,', ''],
#  229: ['The location and area was safe', ''],
#  230: ['Also, they do not help in collecting your bags when you come from long day of shopping.',
#   ''],
#  231: ["The only thing I didn't like was the horrible tea - some awful Earl Grey with the strangest, undefinable taste.",
#   ''],
#  232: ['ok for Manhattan', ''],
#  233: ['Best location!!', ''],
#  234: ['This hotel suits more for business trips rather than for tourists, because Downtown is too far from the most attractions of Manhattan.',
#   ''],
#  235: ['Location is absolutely fantastic.', ''],
#  236: ['Luckily we ignored him and found a wonderful pub down the road.', ''],
#  237: ['Easy access walking and to subway.', ''],
#  238: ['About 20 minutes walk to Times Square', ''],
#  239: ['great location, easy to get to broadway, Gound zero and all the sights and comforts of NYC',
#   ''],
#  240: ['Good location for visiting lower Manhattan.', ''],
#  241: ['Staff were friendly and accommodating.', ''],
#  242: ["Couldn't be in a better location either.", ''],
#  243: ['Even at the night of 31th of December when we was leaving to time square, he stops us at the door of the hotel like if we were thief for one mistake in the restaurant (not our fault) saying that he will charge us the double the check in the restaurant, INCREDIBLE!!',
#   ''],
#  244: ['it is a nice little walk  to and from the javits.', ''],
#  245: ['The view of the Empire state building is a bonus!', ''],
#  246: ['Anthony was amazing!', ''],
#  247: ['The staff, the room.', ''],
#  248: ['Close to trains and restaurants.', ''],
#  249: ['the location was good.', ''],
#  250: ['We enjoyed drinks on the patio of the hotel.', ''],
#  251: ['You get what you pay for!!', ''],
#  252: ['understandable for the view and location.', ''],
#  253: ['My check in experience was not what I expect from a hotel of this caliber,',
#   ''],
#  254: ["I couldn't recommend this place enough, if I ever come back to New York I will be staying at the Y again!",
#   ''],
#  255: ['Design\nLocation', ''],
#  256: ['Very convenient to the subway for getting uptown and downtown.', ''],
#  257: ['Helpful staff', ''],
#  258: ['Staff is always helpful and friendly.', ''],
#  259: ['Location very good.', ''],
#  260: ['I was charged for this hotel even though I canceled 4,days prior to arriving.',
#   ''],
#  261: ['friendly/helpful staff\ngood location\nclean room', ''],
#  262: ['Great location.', ''],
#  263: ['We were upgraded.', ''],
#  264: ['if you get one the view may slightly disappoint you, however this is minor taken into consideration the location of the hotel.',
#   ''],
#  265: ['Great location!', ''],
#  266: ['Made it really easy to get anywhere withing a short time.', ''],
#  267: ['Nice staff.', ''],
#  268: ['friendely staff.', ''],
#  269: ['The staff were very nice and relaxed.', ''],
#  270: ['Cosmo was made the right way at all other restaurants and lounges during our stay',
#   ''],
#  271: ['The staff was very nice and room service very efficient.', ''],
#  272: ['I had to ask for it and got just 60 dollars discount.', ''],
#  273: ['Only its location though in NY so many subway stations that the travel distance shall not be an issue',
#   ''],
#  274: ['NO TEA AND COFFEE IN ROOM!', ''],
#  275: ['Bad wifi', ''],
#  276: ['Breakfast not available in Hotel.', ''],
#  277: ['Location location location!!!', ''],
#  278: ['Rip off!', ''],
#  279: ['Informed that would have a view of Times Square and did not and that was why paying such a lot for the New Years eve had arrange to pay Â£60 dollars extra for view of ball drop',
#   ''],
#  280: ['Reasonably priced Italian restaurant off the paneled lobby.', ''],
#  281: ['Great feel to this hotel, excellent location away from the tourist rush of NYC',
#   ''],
#  282: ['Continental breakfast quality was poor.', ''],
#  283: ['Right across the street from the very relaxing and IMHO the best park in the city Bryant Park.',
#   ''],
#  284: ['the elevator men were really cool.', ''],
#  285: ['The hotel is central', ''],
#  286: ['The location of the apartments was what attracted us and the amazing value for money.',
#   ''],
#  287: ['No room service.', ''],
#  288: ['Wifi connection was not good.', ''],
#  289: ['The location is amazing - right in the heart of the Flatiron District.',
#   ''],
#  290: ['Also just down from Madison Square Park.', ''],
#  291: ['The location was great.', ''],
#  292: ['Good placed in the city, very close to Times Square and Rockfeller center, good restorants and bars close to it.',
#   ''],
#  293: ['Cafeteria was great and they make good food', ''],
#  294: ['ALTHOUGHT i WOULD LIKE TO MAKE A SPECIAL MENTION ABOUT THE CONCIERGE, CHRIS SIMPLY WAS AMAZINGLY KNOWLEDGEABLE, HELPFULL AND VERY PROFESSIONAL.',
#   ''],
#  295: ['Location to parking garage, train stop, restaurants', ''],
#  296: ['Convenient location close to subway.', ''],
#  297: ['The location is wonderful, just two blocks from Central Park.', ''],
#  298: ["The location, it's near a few of our favorite craft beer bars.", ''],
#  299: ['They charged money (5$) just to keep your luggage at the end of the stay, unbelievable.',
#   ''],
#  300: ['While the streets are rather busy during the day the area gets quiet at night.',
#   ''],
#  301: ['Very close to Times Square', ''],
#  302: ['Within walking distance to Columbia University.', '']}

# %%
import pandas as pd
df = pd.read_csv('Data/Hotel_reviews_dataset.csv')
df.head(20)
# Out:
#                                                  Text Sentiment
# 0   The rooms are extremely small, practically onl...  negative
# 1                             Room safe did not work.  negative
# 2                          Mattress very comfortable.  positive
# 3   Very uncomfortable, thin mattress, with plasti...  negative
# 4                                 No bathroom in room  negative
# 5                            The bed was soooo comfy.  positive
# 6   someone must have been smoking in the room nex...  negative
# 7                        The bed is very comfortable.  positive
# 8    Very spacious rooms, quiet and very comfortable.  positive
# 9   For 3 people in a bedroom the sofa bed is a bi...  negative
# 10            Lights in the common room were too dim.  negative
# 11                     Air conditioning working fine.  positive
# 12  So if you're the type that likes to let water ...  negative
# 13  the windows are only single glazed so the heat...  negative
# 14  Terrible, small cubbyholes, which are marketed...  negative
# 15  Corridors filthy\r\nRoom filthy\r\nElectrical ...  negative
# 16             walls seem to have no sound insulation  negative
# 17                   The gym was very small and basic  negative
# 18  The mattresses were too "springy" and uncomfor...  negative
# 19  very light and the comfy of the bed was unbeat...  negative

# %%
from sklearn.datasets import load_breast_cancer
data = load_breast_cancer()

# %%
X=data.data
y=data.target

# %%
X
# Out:
# array([[1.799e+01, 1.038e+01, 1.228e+02, ..., 2.654e-01, 4.601e-01,
#         1.189e-01],
#        [2.057e+01, 1.777e+01, 1.329e+02, ..., 1.860e-01, 2.750e-01,
#         8.902e-02],
#        [1.969e+01, 2.125e+01, 1.300e+02, ..., 2.430e-01, 3.613e-01,
#         8.758e-02],
#        ...,
#        [1.660e+01, 2.808e+01, 1.083e+02, ..., 1.418e-01, 2.218e-01,
#         7.820e-02],
#        [2.060e+01, 2.933e+01, 1.401e+02, ..., 2.650e-01, 4.087e-01,
#         1.240e-01],
#        [7.760e+00, 2.454e+01, 4.792e+01, ..., 0.000e+00, 2.871e-01,
#         7.039e-02]])

# %%
import numpy as np

# %%
np.array([[1],[2], [3]])
# Out:
# array([[1],
#        [2],
#        [3]])
